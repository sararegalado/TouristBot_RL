# %% [markdown]
# # 🌆 TouristBot Environment - Primera Iteración
#
# Este notebook te permite probar el entorno básico de TouristBot.
#
# ## Características de esta versión:
# - ✅ Grid 10x10
# - ✅ 1 agente (turista)
# - ✅ 2 lugares: restaurante y museo
# - ✅ 4 acciones: arriba, abajo, izquierda, derecha
# - ✅ Objetivo: navegar hasta el lugar indicado

# %% [markdown]
# ## 1. Importar el entorno

# %%
import sys
sys.path.append('/Users/sara/Documents/deusto_2025_2026/Aprendizaje por refuerzo/proyecto')

from touristbot_env import TouristBotEnv, PLACE_TYPES
import numpy as np
import time

# %% [markdown]
# ## 2. Crear y probar el entorno básico

# %%
# Crear el entorno
env = TouristBotEnv(goal_type="restaurant")

# Reset para obtener el estado inicial
observation, info = env.reset()

print("Estado inicial del entorno:")
print(f"  Posición del agente: {env.agent_pos}")
print(f"  Objetivo: {info['goal_type']}")
print(f"  Posición del objetivo: {info['goal_position']}")
print(f"  Lugares en el mapa: {env.places}")
print(f"\nObservación: {observation}")
print(f"  [agent_x, agent_y, goal_x, goal_y, goal_type_id]")
# Out:
# 🌆 TouristBot Environment inicializado
#    Grid: 10x10
#    Objetivo inicial: restaurant
# Estado inicial del entorno:
#   Posición del agente: [1, 8]
#   Objetivo: restaurant
#   Posición del objetivo: [6, 1]
#   Lugares en el mapa: {'restaurant': [6, 1], 'museum': [4, 4]}
#
# Observación: [1. 8. 6. 1. 0.]
#   [agent_x, agent_y, goal_x, goal_y, goal_type_id]

# %% [markdown]
# ## 3. Explorar el espacio de acciones

# %%
print("Espacio de acciones:")
print(f"  Tipo: {env.action_space}")
print(f"  Número de acciones: {env.action_space.n}")
print("\nAcciones disponibles:")
print("  0: Arriba (↑)")
print("  1: Abajo (↓)")
print("  2: Izquierda (←)")
print("  3: Derecha (→)")
print("\nEspacio de observación:")
print(f"  Shape: {env.observation_space.shape}")
print(f"  Range: [{env.observation_space.low}, {env.observation_space.high}]")
# Out:
# Espacio de acciones:
#   Tipo: Discrete(4)
#   Número de acciones: 4
#
# Acciones disponibles:
#   0: Arriba (↑)
#   1: Abajo (↓)
#   2: Izquierda (←)
#   3: Derecha (→)
#
# Espacio de observación:
#   Shape: (5,)
#   Range: [[0. 0. 0. 0. 0.], [10. 10. 10. 10. 10.]]

# %% [markdown]
# ## 4. Ejecutar un episodio con acciones aleatorias

# %%
# Reset del entorno
observation, info = env.reset()
env.render()

print("Ejecutando episodio con acciones aleatorias...")
print(f"Objetivo: {env.goal_type} en posición {env.goal_pos}\n")

done = False
episode_reward = 0
action_names = ["↑", "↓", "←", "→"]

while not done:
    # Acción aleatoria
    action = env.action_space.sample()
    
    # Ejecutar acción
    observation, reward, terminated, truncated, info = env.step(action)
    episode_reward += reward
    
    # Renderizar
    env.render()
    
    # Mostrar información cada 10 pasos
    if info['steps'] % 10 == 0:
        print(f"Paso {info['steps']}: Pos={env.agent_pos}, Distancia={info['distance_to_goal']}, Reward acum={episode_reward:.2f}")
    
    done = terminated or truncated
    time.sleep(0.05)

print(f"\n{'='*60}")
if terminated:
    print("🎉 ¡Objetivo alcanzado!")
else:
    print("⏰ Tiempo agotado")
print(f"Pasos totales: {info['steps']}")
print(f"Reward total: {episode_reward:.2f}")
print(f"{'='*60}")

time.sleep(2)
env.close()
# Out:
# Ejecutando episodio con acciones aleatorias...
# Objetivo: restaurant en posición [7, 1]
#
# Paso 10: Pos=[2, 7], Distancia=11, Reward acum=-0.00
# Paso 10: Pos=[2, 7], Distancia=11, Reward acum=-0.00
# Paso 20: Pos=[3, 6], Distancia=9, Reward acum=-0.00
# Paso 20: Pos=[3, 6], Distancia=9, Reward acum=-0.00
# Paso 30: Pos=[6, 3], Distancia=3, Reward acum=2.00
# Paso 30: Pos=[6, 3], Distancia=3, Reward acum=2.00
# Paso 40: Pos=[4, 1], Distancia=3, Reward acum=1.00
# Paso 40: Pos=[4, 1], Distancia=3, Reward acum=1.00
# Paso 50: Pos=[5, 8], Distancia=9, Reward acum=-3.00
# Paso 50: Pos=[5, 8], Distancia=9, Reward acum=-3.00
# Paso 60: Pos=[8, 7], Distancia=7, Reward acum=-3.00
# Paso 60: Pos=[8, 7], Distancia=7, Reward acum=-3.00
# Paso 70: Pos=[9, 9], Distancia=10, Reward acum=-5.50
# Paso 70: Pos=[9, 9], Distancia=10, Reward acum=-5.50
# Paso 80: Pos=[8, 8], Distancia=8, Reward acum=-5.50
# Paso 80: Pos=[8, 8], Distancia=8, Reward acum=-5.50
# Paso 90: Pos=[7, 5], Distancia=4, Reward acum=-4.50
# Paso 90: Pos=[7, 5], Distancia=4, Reward acum=-4.50
# ⏰ Tiempo agotado después de 100 pasos
# Paso 100: Pos=[5, 3], Distancia=4, Reward acum=-10.50
#
# ============================================================
# ⏰ Tiempo agotado
# Pasos totales: 100
# Reward total: -10.50
# ============================================================
# ⏰ Tiempo agotado después de 100 pasos
# Paso 100: Pos=[5, 3], Distancia=4, Reward acum=-10.50
#
# ============================================================
# ⏰ Tiempo agotado
# Pasos totales: 100
# Reward total: -10.50
# ============================================================

# %% [markdown]
# ## 5. Probar con control manual (teclado)

# %%
def play_manual():
    """
    Jugar manualmente con el teclado
    Instrucciones:
    - w: arriba
    - s: abajo
    - a: izquierda
    - d: derecha
    - q: salir
    """
    env = TouristBotEnv(goal_type="museum")
    observation, info = env.reset()
    
    print("Control manual activado")
    print("Instrucciones:")
    print("  w = arriba, s = abajo, a = izquierda, d = derecha, q = salir")
    print(f"\nObjetivo: {env.goal_type} en {env.goal_pos}")
    print("Posición inicial:", env.agent_pos)
    print()
    
    key_map = {'w': 0, 's': 1, 'a': 2, 'd': 3}
    done = False
    
    while not done:
        env.render()
        
        # Leer input del usuario
        key = input("Acción (w/a/s/d/q): ").lower()
        
        if key == 'q':
            print("Saliendo...")
            break
        
        if key not in key_map:
            print("Tecla inválida. Usa w/a/s/d/q")
            continue
        
        action = key_map[key]
        observation, reward, terminated, truncated, info = env.step(action)
        
        print(f"Pos: {env.agent_pos}, Reward: {reward:.2f}, Steps: {info['steps']}")
        
        done = terminated or truncated
    
    env.close()
    print("\n¡Juego terminado!")

# Descomentar para jugar manualmente
play_manual()

# %% [markdown]
# ## 6. Probar diferentes objetivos

# %%
import random

print("Probando con diferentes objetivos...\n")

for i in range(3):
    goal_type = random.choice(PLACE_TYPES)
    env = TouristBotEnv(goal_type=goal_type)
    observation, info = env.reset()
    
    print(f"Episodio {i+1}:")
    print(f"  Objetivo: {goal_type}")
    print(f"  Posición objetivo: {env.goal_pos}")
    print(f"  Posición agente: {env.agent_pos}")
    print(f"  Distancia Manhattan: {abs(env.agent_pos[0]-env.goal_pos[0]) + abs(env.agent_pos[1]-env.goal_pos[1])}")
    print()
    
    env.close()
# Out:
# Probando con diferentes objetivos...
#
# 🌆 TouristBot Environment inicializado
#    Grid: 10x10
#    Objetivo inicial: museum
# Episodio 1:
#   Objetivo: museum
#   Posición objetivo: [5, 1]
#   Posición agente: [1, 8]
#   Distancia Manhattan: 11
#
# 🌆 TouristBot Environment inicializado
#    Grid: 10x10
#    Objetivo inicial: museum
# Episodio 2:
#   Objetivo: museum
#   Posición objetivo: [1, 3]
#   Posición agente: [1, 8]
#   Distancia Manhattan: 5
#
# 🌆 TouristBot Environment inicializado
#    Grid: 10x10
#    Objetivo inicial: restaurant
# Episodio 3:
#   Objetivo: restaurant
#   Posición objetivo: [8, 3]
#   Posición agente: [1, 8]
#   Distancia Manhattan: 12

# %% [markdown]
# ## 7. Verificar compatibilidad con Gymnasium

# %%
from gymnasium.utils.env_checker import check_env

print("Verificando compatibilidad con Gymnasium...")
try:
    env = TouristBotEnv()
    check_env(env.unwrapped, skip_render_check=True)
    print("✅ El entorno es compatible con Gymnasium")
except Exception as e:
    print(f"❌ Error: {e}")
finally:
    env.close()
# Out:
# Verificando compatibilidad con Gymnasium...
# 🌆 TouristBot Environment inicializado
#    Grid: 10x10
#    Objetivo inicial: restaurant
# ✅ El entorno es compatible con Gymnasium
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 🎯 Próximos pasos
#
# Esta es la versión más básica. Las siguientes iteraciones incluirán:
#
# 1. **Más lugares**: cafés, parking, tiendas, hoteles
# 2. **Atributos semánticos**: precio, atmósfera, ocupación
# 3. **Instrucciones en lenguaje natural**: "busca un restaurante barato"
# 4. **Zero-shot classification**: para interpretar intenciones
# 5. **Entrenamiento con PPO**: para aprender políticas óptimas
# 6. **Vista parcial del agente**: observación realista (5x5)
# 7. **Reward shaping**: recompensas por cumplir atributos
